# %%
# welcome abhay you are learning pandas

# %% [markdown]
# what is pandas
# pandas  is open source data analysis library writen in pyton
# it provids rich and highly robust data operations

# %%
import numpy as np 
import pandas as pd

# %%
dict1 = {
    
    "name":['harry','roshan','abhay','nitin'],
    "marks":[92,65,99,67],
    "city":['mum','tha','murb','airoli']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks    city
# 0   harry     92     mum
# 1  roshan     65     tha
# 2   abhay     99    murb
# 3   nitin     67  airoli

# %%
df.to_csv('frinds.csv')   # creating csv file

# %%
df.head(2)   # for show first 2
# Out:
#      name  marks city
# 0   harry     92  mum
# 1  roshan     65  tha

# %%
df.tail(2) #   for last 2
# Out:
#     name  marks    city
# 2  abhay     99    murb
# 3  nitin     67  airoli

# %%
df.describe()   # show static analysis
# Out:
#            marks
# count   4.000000
# mean   80.750000
# std    17.289207
# min    65.000000
# 25%    66.500000
# 50%    79.500000
# 75%    93.750000
# max    99.000000

# %%
df = pd.read_csv("C:/Users/Hp/Downloads/abhay.csv")

print(df.to_string())
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# 5    7.89     2.99
# 6    6.73     2.60
# 7    6.75     2.48
# 8    6.09     2.31
# 9    8.31     3.51
# 10   5.32     1.86
# 11   6.61     2.60
# 12   8.94     3.65
# 13   6.93     2.89
# 14   7.73     3.42
# 15   7.25     3.23
# 16   6.84     2.35
# 17   5.38     2.09
# 18   6.94     2.98
# 19   7.48     2.83
# 20   7.28     3.16
# 21   6.85     2.93
# 22   6.14     2.30
# 23   6.19     2.48
# 24   6.53     2.71
# 25   7.28     3.65
# 26   8.31     3.42
# 27   5.42     2.16
# 28   5.94     2.24
# 29   7.15     3.49
# 30   7.36     3.26
# 31   8.10     3.89
# 32   6.96     3.08
# 33   6.35     2.73
# 34   7.34     3.42
# 35   6.87     2.87
# 36   5.99     2.84
# 37   5.90     2.43
# 38   8.62     4.36
# 39   7.43     3.33
# 40   9.38     4.02
# 41   6.89     2.70
# 42   5.95     2.54
# 43   7.66     2.76
# 44   5.09     1.86
# 45   7.87     3.58
# ...

# %%
newdf = pd.DataFrame(np.random.rand(500,5),index=np.arange(500))
newdf
# Out:
#             0         1         2         3         4
# 0    0.596614  0.909548  0.108733  0.479142  0.600476
# 1    0.882195  0.763416  0.532184  0.416662  0.789427
# 2    0.745386  0.031171  0.705410  0.150157  0.375507
# 3    0.522041  0.727802  0.123513  0.097346  0.464027
# 4    0.017714  0.948371  0.771326  0.714527  0.191490
# ..        ...       ...       ...       ...       ...
# 495  0.256202  0.766357  0.821027  0.683433  0.680159
# 496  0.656256  0.036500  0.947677  0.036194  0.300386
# 497  0.735136  0.021140  0.784368  0.038439  0.493805
# 498  0.640908  0.452909  0.598682  0.858061  0.746408
# 499  0.061437  0.567016  0.976212  0.624783  0.755495
#
# [500 rows x 5 columns]

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     0
# %%
newdf.head(2)
# Out:
#             0         1         2         3         4
# 0  654.000000  0.909548  0.108733  0.479142  0.600476
# 1    0.882195  0.763416  0.532184  0.416662  0.789427

# %%
newdf.columns = list('ABCDE')

# %%
newdf
# Out:
#               A         B         C         D         E
# 0    654.000000  0.909548  0.108733  0.479142  0.600476
# 1      0.882195  0.763416  0.532184  0.416662  0.789427
# 2      0.745386  0.031171  0.705410  0.150157  0.375507
# 3      0.522041  0.727802  0.123513  0.097346  0.464027
# 4      0.017714  0.948371  0.771326  0.714527  0.191490
# ..          ...       ...       ...       ...       ...
# 495    0.256202  0.766357  0.821027  0.683433  0.680159
# 496    0.656256  0.036500  0.947677  0.036194  0.300386
# 497    0.735136  0.021140  0.784368  0.038439  0.493805
# 498    0.640908  0.452909  0.598682  0.858061  0.746408
# 499    0.061437  0.567016  0.976212  0.624783  0.755495
#
# [500 rows x 5 columns]

# %%
newdf.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.532184  0.416662
# 2  0.705410  0.150157

# %%
newdf.head()   #  inspace use for remove A D
# Out:
#             A         B         C         D         E
# 0  654.000000  0.909548  0.108733  0.479142  0.600476
# 1    0.882195  0.763416  0.532184  0.416662  0.789427
# 2    0.745386  0.031171  0.705410  0.150157  0.375507
# 3    0.522041  0.727802  0.123513  0.097346  0.464027
# 4    0.017714  0.948371  0.771326  0.714527  0.191490

# %%
newdf['B'].isnull()    # isnull use for returning null value
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: B, Length: 500, dtype: bool

# %%
newdf['B'] = None

# %%
newdf['B'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 495    True
# 496    True
# 497    True
# 498    True
# 499    True
# Name: B, Length: 500, dtype: bool

# %%
newdf.loc[:,['B']] = 56

# %%
newdf.head()
# Out:
#             A   B         C         D         E
# 0  654.000000  56  0.108733  0.479142  0.600476
# 1    0.882195  56  0.532184  0.416662  0.789427
# 2    0.745386  56  0.705410  0.150157  0.375507
# 3    0.522041  56  0.123513  0.097346  0.464027
# 4    0.017714  56  0.771326  0.714527  0.191490

# %%
df= pd.DataFrame({"name": ['abhay','roshan','abhay'],
    "Toy": [np.nan,'mob','bat'],
    "born": [pd.NaT,pd.Timestamp("1940-04-25"),
           pd.NaT]})

# %%
df.head()
# Out:
#      name  Toy       born
# 0   abhay  NaN        NaT
# 1  roshan  mob 1940-04-25
# 2   abhay  bat        NaT

# %%
df.dropna()    # remove spacific word
# Out:
#      name  Toy       born
# 1  roshan  mob 1940-04-25

# %%
df.drop_duplicates(subset=["name"])  #for deleting duplicate value
# Out:
#      name  Toy       born
# 0   abhay  NaN        NaT
# 1  roshan  mob 1940-04-25

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   Toy     2 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 200.0+ bytes

# %%
df['name'].value_counts(dropna=False)
# Out:
# abhay     2
# roshan    1
# Name: name, dtype: int64

# %%
df['Toy'].value_counts(dropna=True)
# Out:
# mob    1
# bat    1
# Name: Toy, dtype: int64

# %%
df.notnull()
# Out:
#    name    Toy   born
# 0  True  False  False
# 1  True   True   True
# 2  True   True  False

# %%
df.isnull()
# Out:
#     name    Toy   born
# 0  False   True   True
# 1  False  False  False
# 2  False  False   True

# %% [markdown]
# create a data frame which contains only integer with 3 row and 2 columns run following method

# %%
df.describe()
df.mean()
df.corr()
df.count()
df.max()
df.min()
df.median()
df.std()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_15552\2540790412.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe()
# C:\Users\Hp\AppData\Local\Temp\ipykernel_15552\2540790412.py:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.mean()
# C:\Users\Hp\AppData\Local\Temp\ipykernel_15552\2540790412.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# ...

# %%
data = pd.read_excel('filename.xlsx',sheet_name='sheet2')   #for reading sheets
data
data.to_excel('data.xlsx',sheet_name='Sheet2')     #for saving data to sheet 2
