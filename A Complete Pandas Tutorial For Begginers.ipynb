# %%
import numpy as np             # linear algebra
import pandas as pd        # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
train=pd.read_csv("D:/tested.csv")
df=train.copy()

# %% [markdown]
# # 1. The Basics

# %%
# See the first 5 rows
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# last 5 rows.
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
# n_samples x n_features
df.shape
# Out:
# (418, 12)

# %%
#List of all the columns
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Rows index
df.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
# Values with their counts in a particular column
df['Pclass'].value_counts()
# Out:
# 3    218
# 1    107
# 2     93
# Name: Pclass, dtype: int64

# %%
# General description of dataset.
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %% [markdown]
# # 2. Creating DataFrame

# %%
# empty data frame
df_empty=pd.DataFrame()
df_empty.head()  #;)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# From dict
student_dict={'Name':['A','B','C'],'Age':[24,18,17],'Roll':[1,2,3]}
df_student=pd.DataFrame(student_dict).reset_index(drop=True) # without this adds an additional index column in df
df_student.head()
# Out:
#   Name  Age  Roll
# 0    A   24     1
# 1    B   18     2
# 2    C   17     3

# %% [markdown]
# # 3. Treating null values

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# on whole df.
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# on a particular column
df['Age'].isnull().sum()
# Out:
# 86

# %% [markdown]
# # Impute null values

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Sex'].fillna(df['Sex'].mode(),inplace=True)
df['Sex'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # 4. Modify/Add new column(s).
# Adding another column or modify a column

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df['Sex']=df['Sex'].map({"male":'0',"female":"1"})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James   0  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)   1  47.0      1      0
# 2                     Myles, Mr. Thomas Francis   0  62.0      0      0
# 3                              Wirz, Mr. Albert   0  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)   1  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# # Modify Add new column(s).

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James   0  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)   1  47.0      1      0
# 2                     Myles, Mr. Thomas Francis   0  62.0      0      0
# 3                              Wirz, Mr. Albert   0  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)   1  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df['Sex']=df['Sex'].map({"male":'0',"female":"1"})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James  NaN  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  NaN  47.0      1      0
# 2                     Myles, Mr. Thomas Francis  NaN  62.0      0      0
# 3                              Wirz, Mr. Albert  NaN  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  NaN  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# Finding last name and first name from Name column.
df['last_name']=df['Name'].apply(lambda x: x.split(',')[0])
df['first_name']=df['Name'].apply(lambda x: ' '.join(x.split(',')[1:]))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James  NaN  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  NaN  47.0      1      0
# 2                     Myles, Mr. Thomas Francis  NaN  62.0      0      0
# 3                              Wirz, Mr. Albert  NaN  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  NaN  22.0      1      1
#
#     Ticket     Fare Cabin Embarked last_name  \
# 0   330911   7.8292   NaN        Q     Kelly
# 1   363272   7.0000   NaN        S    Wilkes
# 2   240276   9.6875   NaN        Q     Myles
# 3   315154   8.6625   NaN        S      Wirz
# 4  3101298  12.2875   NaN        S  Hirvonen
#
#                             first_name
# 0                            Mr. James
# 1             Mrs. James (Ellen Needs)
# 2                   Mr. Thomas Francis
# 3                           Mr. Albert
# 4   Mrs. Alexander (Helga E Lindqvist)

# %%
# Sets to 1 for men in 3rd class.
df['Thrid&Men']=df.apply(lambda row: int(row['Pclass']==3 and row['Sex']=="0"),axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James  NaN  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  NaN  47.0      1      0
# 2                     Myles, Mr. Thomas Francis  NaN  62.0      0      0
# 3                              Wirz, Mr. Albert  NaN  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  NaN  22.0      1      1
#
#     Ticket     Fare Cabin Embarked last_name  \
# 0   330911   7.8292   NaN        Q     Kelly
# 1   363272   7.0000   NaN        S    Wilkes
# 2   240276   9.6875   NaN        Q     Myles
# 3   315154   8.6625   NaN        S      Wirz
# 4  3101298  12.2875   NaN        S  Hirvonen
#
#                             first_name  Thrid&Men
# 0                            Mr. James          0
# 1             Mrs. James (Ellen Needs)          0
# 2                   Mr. Thomas Francis          0
# 3                           Mr. Albert          0
# 4   Mrs. Alexander (Helga E Lindqvist)          0

# %%
def findAgeGroup(age):
    if age<18:
        return 1
    elif age>=18 and age<40:
        return 2
    elif age>=40 and age<60:
        return 3
    else:
        return 4
df['Age_group']=df['Age'].apply(lambda x: findAgeGroup(x))
# Calling a custom function.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James  NaN  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  NaN  47.0      1      0
# 2                     Myles, Mr. Thomas Francis  NaN  62.0      0      0
# 3                              Wirz, Mr. Albert  NaN  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  NaN  22.0      1      1
#
#     Ticket     Fare Cabin Embarked last_name  \
# 0   330911   7.8292   NaN        Q     Kelly
# 1   363272   7.0000   NaN        S    Wilkes
# 2   240276   9.6875   NaN        Q     Myles
# 3   315154   8.6625   NaN        S      Wirz
# 4  3101298  12.2875   NaN        S  Hirvonen
#
#                             first_name  Thrid&Men  Age_group
# 0                            Mr. James          0          2
# 1             Mrs. James (Ellen Needs)          0          3
# 2                   Mr. Thomas Francis          0          4
# 3                           Mr. Albert          0          2
# 4   Mrs. Alexander (Helga E Lindqvist)          0          2

# %% [markdown]
# # 5. Deleting columns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James  NaN  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  NaN  47.0      1      0
# 2                     Myles, Mr. Thomas Francis  NaN  62.0      0      0
# 3                              Wirz, Mr. Albert  NaN  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  NaN  22.0      1      1
#
#     Ticket     Fare Cabin Embarked last_name  \
# 0   330911   7.8292   NaN        Q     Kelly
# 1   363272   7.0000   NaN        S    Wilkes
# 2   240276   9.6875   NaN        Q     Myles
# 3   315154   8.6625   NaN        S      Wirz
# 4  3101298  12.2875   NaN        S  Hirvonen
#
#                             first_name  Thrid&Men  Age_group
# 0                            Mr. James          0          2
# 1             Mrs. James (Ellen Needs)          0          3
# 2                   Mr. Thomas Francis          0          4
# 3                           Mr. Albert          0          2
# 4   Mrs. Alexander (Helga E Lindqvist)          0          2

# %%
df=df.drop(['PassengerId'],axis=1)
#df=df.drop(['PassengerId'],axis=1,inplace=True)
df.head()
# Out:
#    Survived  Pclass                                          Name  Sex   Age  \
# 0         0       3                              Kelly, Mr. James  NaN  34.5
# 1         1       3              Wilkes, Mrs. James (Ellen Needs)  NaN  47.0
# 2         0       2                     Myles, Mr. Thomas Francis  NaN  62.0
# 3         0       3                              Wirz, Mr. Albert  NaN  27.0
# 4         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  NaN  22.0
#
#    SibSp  Parch   Ticket     Fare Cabin Embarked last_name  \
# 0      0      0   330911   7.8292   NaN        Q     Kelly
# 1      1      0   363272   7.0000   NaN        S    Wilkes
# 2      0      0   240276   9.6875   NaN        Q     Myles
# 3      0      0   315154   8.6625   NaN        S      Wirz
# 4      1      1  3101298  12.2875   NaN        S  Hirvonen
#
#                             first_name  Thrid&Men  Age_group
# 0                            Mr. James          0          2
# 1             Mrs. James (Ellen Needs)          0          3
# 2                   Mr. Thomas Francis          0          4
# 3                           Mr. Albert          0          2
# 4   Mrs. Alexander (Helga E Lindqvist)          0          2

# %% [markdown]
# # 6. Renaming columns

# %%
# Lets try to rename some columns. 
df=df.rename(columns={'Sex':'Gender','Name':'Full Name','last_name':'Surname','first_name':'Name'})
df.head()
# Out:
#    Survived  Pclass                                     Full Name Gender  \
# 0         0       3                              Kelly, Mr. James    NaN
# 1         1       3              Wilkes, Mrs. James (Ellen Needs)    NaN
# 2         0       2                     Myles, Mr. Thomas Francis    NaN
# 3         0       3                              Wirz, Mr. Albert    NaN
# 4         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    NaN
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked   Surname  \
# 0  34.5      0      0   330911   7.8292   NaN        Q     Kelly
# 1  47.0      1      0   363272   7.0000   NaN        S    Wilkes
# 2  62.0      0      0   240276   9.6875   NaN        Q     Myles
# 3  27.0      0      0   315154   8.6625   NaN        S      Wirz
# 4  22.0      1      1  3101298  12.2875   NaN        S  Hirvonen
#
#                                   Name  Thrid&Men  Age_group
# 0                            Mr. James          0          2
# 1             Mrs. James (Ellen Needs)          0          3
# 2                   Mr. Thomas Francis          0          4
# 3                           Mr. Albert          0          2
# 4   Mrs. Alexander (Helga E Lindqvist)          0          2

# %% [markdown]
# # 7.i Slicing DataFrame

# %%
df.head()
# Out:
#    Survived  Pclass                                     Full Name Gender  \
# 0         0       3                              Kelly, Mr. James    NaN
# 1         1       3              Wilkes, Mrs. James (Ellen Needs)    NaN
# 2         0       2                     Myles, Mr. Thomas Francis    NaN
# 3         0       3                              Wirz, Mr. Albert    NaN
# 4         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    NaN
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked   Surname  \
# 0  34.5      0      0   330911   7.8292   NaN        Q     Kelly
# 1  47.0      1      0   363272   7.0000   NaN        S    Wilkes
# 2  62.0      0      0   240276   9.6875   NaN        Q     Myles
# 3  27.0      0      0   315154   8.6625   NaN        S      Wirz
# 4  22.0      1      1  3101298  12.2875   NaN        S  Hirvonen
#
#                                   Name  Thrid&Men  Age_group
# 0                            Mr. James          0          2
# 1             Mrs. James (Ellen Needs)          0          3
# 2                   Mr. Thomas Francis          0          4
# 3                           Mr. Albert          0          2
# 4   Mrs. Alexander (Helga E Lindqvist)          0          2

# %%
# All rows with pclass==3
df_third_class=df[df['Pclass']==3].reset_index(drop=True) # w/0 drop=True it actually adds a index column rather.
df_third_class.head()
# Out:
#    Survived  Pclass                                     Full Name Gender  \
# 0         0       3                              Kelly, Mr. James    NaN
# 1         1       3              Wilkes, Mrs. James (Ellen Needs)    NaN
# 2         0       3                              Wirz, Mr. Albert    NaN
# 3         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    NaN
# 4         0       3                    Svensson, Mr. Johan Cervin    NaN
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked   Surname  \
# 0  34.5      0      0   330911   7.8292   NaN        Q     Kelly
# 1  47.0      1      0   363272   7.0000   NaN        S    Wilkes
# 2  27.0      0      0   315154   8.6625   NaN        S      Wirz
# 3  22.0      1      1  3101298  12.2875   NaN        S  Hirvonen
# 4  14.0      0      0     7538   9.2250   NaN        S  Svensson
#
#                                   Name  Thrid&Men  Age_group
# 0                            Mr. James          0          2
# 1             Mrs. James (Ellen Needs)          0          3
# 2                           Mr. Albert          0          2
# 3   Mrs. Alexander (Helga E Lindqvist)          0          2
# 4                     Mr. Johan Cervin          0          1

# %%
# Females with age > 60
df_aged=df[(df['Age']>60) & (df['Gender']=="1")]
df_aged.head()
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Full Name, Gender, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Surname, Name, Thrid&Men, Age_group]
# Index: []

# %%
# Selecting some columns.
df1=df[['Age','Pclass','Gender']]
df1.head()
# Out:
#     Age  Pclass Gender
# 0  34.5       3    NaN
# 1  47.0       3    NaN
# 2  62.0       2    NaN
# 3  27.0       3    NaN
# 4  22.0       3    NaN

# %%
# Select numerical columns only
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

df_num = df.select_dtypes(include=numerics)
df_num.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Thrid&Men  Age_group
# 0         0       3  34.5      0      0   7.8292          0          2
# 1         1       3  47.0      1      0   7.0000          0          3
# 2         0       2  62.0      0      0   9.6875          0          4
# 3         0       3  27.0      0      0   8.6625          0          2
# 4         1       3  22.0      1      1  12.2875          0          2

# %%
# categorical columns
df_cat=df.select_dtypes(include=['object'])
df_cat.head()
# Out:
#                                       Full Name Gender   Ticket Cabin  \
# 0                              Kelly, Mr. James    NaN   330911   NaN
# 1              Wilkes, Mrs. James (Ellen Needs)    NaN   363272   NaN
# 2                     Myles, Mr. Thomas Francis    NaN   240276   NaN
# 3                              Wirz, Mr. Albert    NaN   315154   NaN
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    NaN  3101298   NaN
#
#   Embarked   Surname                                 Name
# 0        Q     Kelly                            Mr. James
# 1        S    Wilkes             Mrs. James (Ellen Needs)
# 2        Q     Myles                   Mr. Thomas Francis
# 3        S      Wirz                           Mr. Albert
# 4        S  Hirvonen   Mrs. Alexander (Helga E Lindqvist)

# %% [markdown]
# # 7.ii Slicing using iloc and loc

# %% [markdown]
# # iloc

# %%
df.head()
# Out:
#    Survived  Pclass                                     Full Name Gender  \
# 0         0       3                              Kelly, Mr. James    NaN
# 1         1       3              Wilkes, Mrs. James (Ellen Needs)    NaN
# 2         0       2                     Myles, Mr. Thomas Francis    NaN
# 3         0       3                              Wirz, Mr. Albert    NaN
# 4         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    NaN
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked   Surname  \
# 0  34.5      0      0   330911   7.8292   NaN        Q     Kelly
# 1  47.0      1      0   363272   7.0000   NaN        S    Wilkes
# 2  62.0      0      0   240276   9.6875   NaN        Q     Myles
# 3  27.0      0      0   315154   8.6625   NaN        S      Wirz
# 4  22.0      1      1  3101298  12.2875   NaN        S  Hirvonen
#
#                                   Name  Thrid&Men  Age_group
# 0                            Mr. James          0          2
# 1             Mrs. James (Ellen Needs)          0          3
# 2                   Mr. Thomas Francis          0          4
# 3                           Mr. Albert          0          2
# 4   Mrs. Alexander (Helga E Lindqvist)          0          2

# %%
# First 100 rows & all columns
df_sub1=df.iloc[0:100,:]
df_sub1.head()
# Out:
#    Survived  Pclass                                     Full Name Gender  \
# 0         0       3                              Kelly, Mr. James    NaN
# 1         1       3              Wilkes, Mrs. James (Ellen Needs)    NaN
# 2         0       2                     Myles, Mr. Thomas Francis    NaN
# 3         0       3                              Wirz, Mr. Albert    NaN
# 4         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    NaN
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked   Surname  \
# 0  34.5      0      0   330911   7.8292   NaN        Q     Kelly
# 1  47.0      1      0   363272   7.0000   NaN        S    Wilkes
# 2  62.0      0      0   240276   9.6875   NaN        Q     Myles
# 3  27.0      0      0   315154   8.6625   NaN        S      Wirz
# 4  22.0      1      1  3101298  12.2875   NaN        S  Hirvonen
#
#                                   Name  Thrid&Men  Age_group
# 0                            Mr. James          0          2
# 1             Mrs. James (Ellen Needs)          0          3
# 2                   Mr. Thomas Francis          0          4
# 3                           Mr. Albert          0          2
# 4   Mrs. Alexander (Helga E Lindqvist)          0          2

# %%
#First 250 rows with a subset of columns

#df_sub2=df.iloc[:250,['Age']] 
# This will throw an error as iloc only consumes integres as indices.

df_sub2=df.iloc[:250,[1,8]] 
#Returns first 250 rows and columns at those indices in df.columns.
df_sub2.head()
# Out:
#    Pclass     Fare
# 0       3   7.8292
# 1       3   7.0000
# 2       2   9.6875
# 3       3   8.6625
# 4       3  12.2875

# %% [markdown]
# # loc

# %%
df.head()
# Out:
#    Survived  Pclass                                     Full Name Gender  \
# 0         0       3                              Kelly, Mr. James    NaN
# 1         1       3              Wilkes, Mrs. James (Ellen Needs)    NaN
# 2         0       2                     Myles, Mr. Thomas Francis    NaN
# 3         0       3                              Wirz, Mr. Albert    NaN
# 4         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    NaN
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked   Surname  \
# 0  34.5      0      0   330911   7.8292   NaN        Q     Kelly
# 1  47.0      1      0   363272   7.0000   NaN        S    Wilkes
# 2  62.0      0      0   240276   9.6875   NaN        Q     Myles
# 3  27.0      0      0   315154   8.6625   NaN        S      Wirz
# 4  22.0      1      1  3101298  12.2875   NaN        S  Hirvonen
#
#                                   Name  Thrid&Men  Age_group
# 0                            Mr. James          0          2
# 1             Mrs. James (Ellen Needs)          0          3
# 2                   Mr. Thomas Francis          0          4
# 3                           Mr. Albert          0          2
# 4   Mrs. Alexander (Helga E Lindqvist)          0          2

# %%
# First 500 rows.
df_sub3=df.loc[:500,:]

# %%
# Gender and age of age >50
df_sub4=df.loc[(df['Age']>50),['Gender','Age']]
df_sub4.head()
# Out:
#    Gender   Age
# 2     NaN  62.0
# 13    NaN  63.0
# 20    NaN  55.0
# 48    NaN  60.0
# 69    NaN  60.0

# %% [markdown]
# # 8. Adding a row

# %%
df.head()
# Out:
#    Survived  Pclass                                     Full Name Gender  \
# 0         0       3                              Kelly, Mr. James    NaN
# 1         1       3              Wilkes, Mrs. James (Ellen Needs)    NaN
# 2         0       2                     Myles, Mr. Thomas Francis    NaN
# 3         0       3                              Wirz, Mr. Albert    NaN
# 4         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    NaN
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked   Surname  \
# 0  34.5      0      0   330911   7.8292   NaN        Q     Kelly
# 1  47.0      1      0   363272   7.0000   NaN        S    Wilkes
# 2  62.0      0      0   240276   9.6875   NaN        Q     Myles
# 3  27.0      0      0   315154   8.6625   NaN        S      Wirz
# 4  22.0      1      1  3101298  12.2875   NaN        S  Hirvonen
#
#                                   Name  Thrid&Men  Age_group
# 0                            Mr. James          0          2
# 1             Mrs. James (Ellen Needs)          0          3
# 2                   Mr. Thomas Francis          0          4
# 3                           Mr. Albert          0          2
# 4   Mrs. Alexander (Helga E Lindqvist)          0          2

# %%
# Adding row using 'append' function
row=dict({'Age':24,'Full Name':'Peter','Survived':'Y'})
df=df.append(row,ignore_index=True)
# assumes Nan for absent keys(columns)
df.tail()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_1840\3299790653.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(row,ignore_index=True)
#     Survived  Pclass                     Full Name Gender       Age  SibSp  \
# 415        0     3.0  Saether, Mr. Simon Sivertsen    NaN  38.50000    0.0
# 416        0     3.0           Ware, Mr. Frederick    NaN  30.27259    0.0
# 417        0     3.0      Peter, Master. Michael J    NaN  30.27259    1.0
# 418        Y     NaN                         Peter    NaN  24.00000    NaN
# 419        Y     NaN                         Peter    NaN  24.00000    NaN
#
#      Parch              Ticket     Fare Cabin Embarked  Surname  \
# 415    0.0  SOTON/O.Q. 3101262   7.2500   NaN        S  Saether
# 416    0.0              359309   8.0500   NaN        S     Ware
# 417    1.0                2668  22.3583   NaN        C    Peter
# 418    NaN                 NaN      NaN   NaN      NaN      NaN
# 419    NaN                 NaN      NaN   NaN      NaN      NaN
#
#                      Name  Thrid&Men  Age_group
# 415   Mr. Simon Sivertsen        0.0        2.0
# 416         Mr. Frederick        0.0        2.0
# 417     Master. Michael J        0.0        2.0
# 418                   NaN        NaN        NaN
# 419                   NaN        NaN        NaN

# %%
# Adding new row using loc
df.loc[len(df.index)]=row
df.tail()
# Out:
#     Survived  Pclass                 Full Name Gender       Age  SibSp  Parch  \
# 416        0     3.0       Ware, Mr. Frederick    NaN  30.27259    0.0    0.0
# 417        0     3.0  Peter, Master. Michael J    NaN  30.27259    1.0    1.0
# 418        Y     NaN                     Peter    NaN  24.00000    NaN    NaN
# 419        Y     NaN                     Peter    NaN  24.00000    NaN    NaN
# 420        Y     NaN                     Peter    NaN  24.00000    NaN    NaN
#
#      Ticket     Fare Cabin Embarked Surname                Name  Thrid&Men  \
# 416  359309   8.0500   NaN        S    Ware       Mr. Frederick        0.0
# 417    2668  22.3583   NaN        C   Peter   Master. Michael J        0.0
# 418     NaN      NaN   NaN      NaN     NaN                 NaN        NaN
# 419     NaN      NaN   NaN      NaN     NaN                 NaN        NaN
# 420     NaN      NaN   NaN      NaN     NaN                 NaN        NaN
#
#      Age_group
# 416        2.0
# 417        2.0
# 418        NaN
# 419        NaN
# 420        NaN

# %% [markdown]
# # 9. Dropping row(s)

# %%
df=df.drop(df.index[-1],axis=0) # Deletes last row
df.head()
# Out:
#   Survived  Pclass                                     Full Name Gender   Age  \
# 0        0     3.0                              Kelly, Mr. James    NaN  34.5
# 1        1     3.0              Wilkes, Mrs. James (Ellen Needs)    NaN  47.0
# 2        0     2.0                     Myles, Mr. Thomas Francis    NaN  62.0
# 3        0     3.0                              Wirz, Mr. Albert    NaN  27.0
# 4        1     3.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    NaN  22.0
#
#    SibSp  Parch   Ticket     Fare Cabin Embarked   Surname  \
# 0    0.0    0.0   330911   7.8292   NaN        Q     Kelly
# 1    1.0    0.0   363272   7.0000   NaN        S    Wilkes
# 2    0.0    0.0   240276   9.6875   NaN        Q     Myles
# 3    0.0    0.0   315154   8.6625   NaN        S      Wirz
# 4    1.0    1.0  3101298  12.2875   NaN        S  Hirvonen
#
#                                   Name  Thrid&Men  Age_group
# 0                            Mr. James        0.0        2.0
# 1             Mrs. James (Ellen Needs)        0.0        3.0
# 2                   Mr. Thomas Francis        0.0        4.0
# 3                           Mr. Albert        0.0        2.0
# 4   Mrs. Alexander (Helga E Lindqvist)        0.0        2.0

# %% [markdown]
# # 10. Sorting

# %%
df.head()
# Out:
#   Survived  Pclass                                     Full Name Gender   Age  \
# 0        0     3.0                              Kelly, Mr. James    NaN  34.5
# 1        1     3.0              Wilkes, Mrs. James (Ellen Needs)    NaN  47.0
# 2        0     2.0                     Myles, Mr. Thomas Francis    NaN  62.0
# 3        0     3.0                              Wirz, Mr. Albert    NaN  27.0
# 4        1     3.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    NaN  22.0
#
#    SibSp  Parch   Ticket     Fare Cabin Embarked   Surname  \
# 0    0.0    0.0   330911   7.8292   NaN        Q     Kelly
# 1    1.0    0.0   363272   7.0000   NaN        S    Wilkes
# 2    0.0    0.0   240276   9.6875   NaN        Q     Myles
# 3    0.0    0.0   315154   8.6625   NaN        S      Wirz
# 4    1.0    1.0  3101298  12.2875   NaN        S  Hirvonen
#
#                                   Name  Thrid&Men  Age_group
# 0                            Mr. James        0.0        2.0
# 1             Mrs. James (Ellen Needs)        0.0        3.0
# 2                   Mr. Thomas Francis        0.0        4.0
# 3                           Mr. Albert        0.0        2.0
# 4   Mrs. Alexander (Helga E Lindqvist)        0.0        2.0

# %%
# sorting by age say in decreasing order.
df=df.sort_values(by=['Age'],ascending=False) # can specify multiple columns in a list as well.
df.head()
# Out:
#     Survived  Pclass                                          Full Name  \
# 96         1     1.0  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81         0     1.0                                 Straus, Mr. Isidor
# 179        1     1.0  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 236        0     1.0                           Warren, Mr. Frank Manley
# 305        1     1.0  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
#
#     Gender   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked  \
# 96     NaN  76.0    1.0    0.0     19877   78.8500      C46        S
# 81     NaN  67.0    1.0    0.0  PC 17483  221.7792  C55 C57        S
# 179    NaN  64.0    0.0    2.0  PC 17756   83.1583      E45        C
# 236    NaN  64.0    1.0    0.0    110813   75.2500      D37        C
# 305    NaN  64.0    1.0    1.0    112901   26.5500      B26        S
#
#        Surname                                               Name  Thrid&Men  \
# 96   Cavendish        Mrs. Tyrell William (Julia Florence Siegel)        0.0
# 81      Straus                                         Mr. Isidor        0.0
# 179    Compton       Mrs. Alexander Taylor (Mary Eliza Ingersoll)        0.0
# 236     Warren                                   Mr. Frank Manley        0.0
# 305     Crosby   Mrs. Edward Gifford (Catherine Elizabeth Hals...        0.0
#
#      Age_group
# 96         4.0
# 81         4.0
# 179        4.0
# 236        4.0
# 305        4.0

# %% [markdown]
# # 11. Joins

# %% [raw]
#  create two separate data frames and try all 5 (Cross,Inner, Left, Right,and Outer Joins).

# %%
sno=[i+1 for i in range(100)]
marks=np.random.randint(100,size=100)
print(len(marks))
marks_df=pd.DataFrame({'Sno':sno,'Marks':marks})
marks_df.head()
# Out:
# 100
#    Sno  Marks
# 0    1     15
# 1    2     35
# 2    3     47
# 3    4     61
# 4    5     72

# %%
sno=[i+1 for i in range(100)]
age=np.random.randint(100,size=100)
print(len(marks))
age_df=pd.DataFrame({'Sno':sno,'Age':age})
age_df.head()
# Out:
# 100
#    Sno  Age
# 0    1   55
# 1    2   87
# 2    3   24
# 3    4   11
# 4    5   73

# %%
cross_join=pd.merge(marks_df,age_df,how='cross')
print(cross_join.shape)
cross_join.head()
# Out:
# (10000, 4)
#    Sno_x  Marks  Sno_y  Age
# 0      1     15      1   55
# 1      1     15      2   87
# 2      1     15      3   24
# 3      1     15      4   11
# 4      1     15      5   73

# %% [markdown]
# # Inner Join

# %%
inner_join=pd.merge(age_df,marks_df,how='inner',on='Sno') # 'how' defaults to 'inner' only.
print(inner_join.shape)
inner_join.head()
# Out:
# (100, 3)
#    Sno  Age  Marks
# 0    1   55     15
# 1    2   87     35
# 2    3   24     47
# 3    4   11     61
# 4    5   73     72

# %% [markdown]
# # Left and Right Outer Join(s)

# %% [raw]
#  add some more rows to either frame so that left and right outer join makes sense

# %%
age_df.loc[len(age_df.index)]={'Sno':101,'Age':23}
age_df.loc[len(age_df.index)]={'Sno':102,'Age':27}
age_df.loc[len(age_df.index)]={'Sno':104,'Age':29}
age_df.loc[len(age_df.index)]={'Sno':103,'Age':32}
age_df.loc[len(age_df.index)]={'Sno':105,'Age':53}

# %%
#left join
left_join=pd.merge(age_df,marks_df,how='left',on='Sno')
print(left_join.shape)
left_join.tail()
# Out:
# (105, 3)
#      Sno  Age  Marks
# 100  101   23    NaN
# 101  102   27    NaN
# 102  104   29    NaN
# 103  103   32    NaN
# 104  105   53    NaN

# %%
#Marks=Nan confirms the left join.

# %%
#right join
right_join=pd.merge(marks_df,age_df,how='right',on='Sno')
print(right_join.shape)
right_join.tail()
# Out:
# (105, 3)
#      Sno  Marks  Age
# 100  101    NaN   23
# 101  102    NaN   27
# 102  104    NaN   29
# 103  103    NaN   32
# 104  105    NaN   53

# %%
#Marks=Nan confirms the right join in this case as the order of input frames is also reversed.

# %% [markdown]
# # Full outer join
# One last time, lets modify the marks frame also to test Full outer join.

# %%
marks_df.loc[len(marks_df.index)]={'Sno':106,'Marks':79}
marks_df.tail()
# Out:
#      Sno  Marks
# 96    97      1
# 97    98     75
# 98    99     61
# 99   100     39
# 100  106     79

# %%
#outer join
out_join=pd.merge(marks_df,age_df,how='outer',on='Sno')
print(out_join.shape)
out_join.tail(10)
# Out:
# (106, 3)
#      Sno  Marks   Age
# 96    97    1.0  26.0
# 97    98   75.0  55.0
# 98    99   61.0  94.0
# 99   100   39.0  26.0
# 100  106   79.0   NaN
# 101  101    NaN  23.0
# 102  102    NaN  27.0
# 103  104    NaN  29.0
# 104  103    NaN  32.0
# 105  105    NaN  53.0

# %%
#Row index 100 is added in putput which confirms the full outer join

# %% [markdown]
# # 12. Groupby

# %%
df.head() #old data set
# Out:
#     Survived  Pclass                                          Full Name  \
# 96         1     1.0  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81         0     1.0                                 Straus, Mr. Isidor
# 179        1     1.0  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 236        0     1.0                           Warren, Mr. Frank Manley
# 305        1     1.0  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
#
#     Gender   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked  \
# 96     NaN  76.0    1.0    0.0     19877   78.8500      C46        S
# 81     NaN  67.0    1.0    0.0  PC 17483  221.7792  C55 C57        S
# 179    NaN  64.0    0.0    2.0  PC 17756   83.1583      E45        C
# 236    NaN  64.0    1.0    0.0    110813   75.2500      D37        C
# 305    NaN  64.0    1.0    1.0    112901   26.5500      B26        S
#
#        Surname                                               Name  Thrid&Men  \
# 96   Cavendish        Mrs. Tyrell William (Julia Florence Siegel)        0.0
# 81      Straus                                         Mr. Isidor        0.0
# 179    Compton       Mrs. Alexander Taylor (Mary Eliza Ingersoll)        0.0
# 236     Warren                                   Mr. Frank Manley        0.0
# 305     Crosby   Mrs. Edward Gifford (Catherine Elizabeth Hals...        0.0
#
#      Age_group
# 96         4.0
# 81         4.0
# 179        4.0
# 236        4.0
# 305        4.0

# %% [raw]
# Before, we move onto Groupby in pandas, lets recollect groupby from SQL. A SQL query, may contain hese parts (some might be optional like having etc...):
# Table name (from)
# Some condition to filter rows (where clause)
# Attribute to groupby on (groupby attributes)
# Filter rows after groupby (having clause)
# Display attributes in the final result. (select)
# Let's now see how to mimic this in Pandas ;)

# %%
df.head()
# Out:
#     Survived  Pclass                                          Full Name  \
# 96         1     1.0  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81         0     1.0                                 Straus, Mr. Isidor
# 179        1     1.0  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 236        0     1.0                           Warren, Mr. Frank Manley
# 305        1     1.0  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
#
#     Gender   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked  \
# 96     NaN  76.0    1.0    0.0     19877   78.8500      C46        S
# 81     NaN  67.0    1.0    0.0  PC 17483  221.7792  C55 C57        S
# 179    NaN  64.0    0.0    2.0  PC 17756   83.1583      E45        C
# 236    NaN  64.0    1.0    0.0    110813   75.2500      D37        C
# 305    NaN  64.0    1.0    1.0    112901   26.5500      B26        S
#
#        Surname                                               Name  Thrid&Men  \
# 96   Cavendish        Mrs. Tyrell William (Julia Florence Siegel)        0.0
# 81      Straus                                         Mr. Isidor        0.0
# 179    Compton       Mrs. Alexander Taylor (Mary Eliza Ingersoll)        0.0
# 236     Warren                                   Mr. Frank Manley        0.0
# 305     Crosby   Mrs. Edward Gifford (Catherine Elizabeth Hals...        0.0
#
#      Age_group
# 96         4.0
# 81         4.0
# 179        4.0
# 236        4.0
# 305        4.0

# %%
groups=df.groupby(['Pclass'])
# uncomment this: 
# groups.groups
groups.get_group(1) # Give some another no say 2 or 3 for its Pclass.
# Out:
#     Survived  Pclass                                          Full Name  \
# 96         1     1.0  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81         0     1.0                                 Straus, Mr. Isidor
# 179        1     1.0  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 236        0     1.0                           Warren, Mr. Frank Manley
# 305        1     1.0  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# ..       ...     ...                                                ...
# 182        1     1.0  Marvin, Mrs. Daniel Warner (Mary Graham Carmic...
# 395        1     1.0     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 403        0     1.0                             Carrau, Mr. Jose Pedro
# 64         0     1.0                        Ryerson, Master. John Borie
# 196        0     1.0                    Spedden, Master. Robert Douglas
#
#     Gender   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked  \
# 96     NaN  76.0    1.0    0.0     19877   78.8500              C46        S
# 81     NaN  67.0    1.0    0.0  PC 17483  221.7792          C55 C57        S
# 179    NaN  64.0    0.0    2.0  PC 17756   83.1583              E45        C
# 236    NaN  64.0    1.0    0.0    110813   75.2500              D37        C
# 305    NaN  64.0    1.0    1.0    112901   26.5500              B26        S
# ..     ...   ...    ...    ...       ...       ...              ...      ...
# 182    NaN  18.0    1.0    0.0    113773   53.1000              D30        S
# 395    NaN  18.0    1.0    0.0     13695   60.0000              C31        S
# 403    NaN  17.0    0.0    0.0    113059   47.1000              NaN        S
# 64     NaN  13.0    2.0    2.0  PC 17608  262.3750  B57 B59 B63 B66        C
# 196    NaN   6.0    0.0    2.0     16966  134.5000              E34        C
#
#        Surname                                               Name  Thrid&Men  \
# 96   Cavendish        Mrs. Tyrell William (Julia Florence Siegel)        0.0
# 81      Straus                                         Mr. Isidor        0.0
# 179    Compton       Mrs. Alexander Taylor (Mary Eliza Ingersoll)        0.0
# 236     Warren                                   Mr. Frank Manley        0.0
# 305     Crosby   Mrs. Edward Gifford (Catherine Elizabeth Hals...        0.0
# ..         ...                                                ...        ...
# 182     Marvin   Mrs. Daniel Warner (Mary Graham Carmichael Fa...        0.0
# 395      Smith            Mrs. Lucien Philip (Mary Eloise Hughes)        0.0
# 403     Carrau                                     Mr. Jose Pedro        0.0
# 64     Ryerson                                 Master. John Borie        0.0
# 196    Spedden                             Master. Robert Douglas        0.0
#
#      Age_group
# 96         4.0
# 81         4.0
# 179        4.0
# 236        4.0
# 305        4.0
# ..         ...
# 182        2.0
# 395        2.0
# 403        1.0
# 64         1.0
# 196        1.0
#
# [107 rows x 15 columns]

# %%
#Average Age per Pclass
df_grp1=df.groupby(['Pclass'])
#df_grp1.head()

# %%
#Average Age per Pclass
df_grp1['Age'].mean()
# Out:
# Pclass
# 1.0    40.022928
# 2.0    28.857881
# 3.0    26.090397
# Name: Age, dtype: float64

# %%
# Min/Max age per Pclass
df_grp1['Age'].min() #max()
# Out:
# Pclass
# 1.0    6.00
# 2.0    0.92
# 3.0    0.17
# Name: Age, dtype: float64

# %%
# Count
df_grp1['Age'].count()
# Out:
# Pclass
# 1.0    107
# 2.0     93
# 3.0    218
# Name: Age, dtype: int64

# %% [markdown]
# # Using agg() function.¶
# We can use the aggregate fucntion to aggregate results based on some column or our custom condition

# %%
df=train.copy()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# Average per Pclass using 'agg' this time
df_grp2=df.groupby(['Pclass']).agg({'Age':lambda x: np.mean(x)}) 
df_grp2.head()
# Out:
#               Age
# Pclass
# 1       40.918367
# 2       28.777500
# 3       24.027945

# %%
# Min/Max,count,Sum for each Pclass usign agg function
df_grp3=df.groupby(['Pclass']).agg({'Age':'min'}).rename(columns={'Age':'Min Age'})
# Use 'max'/'sum' etc. for that operation. Note that this ignores 'nan' values.
df_grp3.head()
# Out:
#         Min Age
# Pclass
# 1          6.00
# 2          0.92
# 3          0.17

# %%
# Names of all the pasengers in that class.
df_grp4=df.groupby(['Pclass']).agg({'Name':lambda x:', '.join(x)})
df_grp4.head()
# Out:
#                                                      Name
# Pclass
# 1       Jones, Mr. Charles Cresson, Snyder, Mrs. John ...
# 2       Myles, Mr. Thomas Francis, Caldwell, Mr. Alber...
# 3       Kelly, Mr. James, Wilkes, Mrs. James (Ellen Ne...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
#Note one thing that we can use multile agg functions on a single attribute by providing list in value part

# %%
df_grp5=df.groupby(['Pclass']).agg({'Age':['max','min']})
df_grp5.head() # Creates a MultiOndex Dataframe
# Out:
#          Age
#          max   min
# Pclass
# 1       76.0  6.00
# 2       63.0  0.92
# 3       60.5  0.17

# %% [markdown]
# # Bonus: Iterating over rows in dataframe

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
for index,row in df.iterrows():
    # do something with row, say:
    #print(row)
    pass

# %%
#Ideally for this we can use 'apply' method also as we saw in adding/modifying the column section.

# %% [markdown]
# # Rough

# %%
arr1=np.random.randint(100,size=(100,1))
arr2=np.random.randint(100,size=(100))
arr1
# Out:
# array([[10],
#        [38],
#        [81],
#        [ 2],
#        [35],
#        [41],
#        [21],
#        [85],
#        [81],
#        [71],
#        [36],
#        [43],
#        [98],
#        [73],
#        [56],
#        [25],
#        [61],
#        [32],
#        [32],
#        [74],
#        [47],
#        [95],
#        [49],
#        [67],
#        [94],
#        [28],
#        [42],
#        [30],
#        [81],
#        [91],
#        [77],
#        [ 1],
#        [68],
#        [51],
#        [38],
#        [77],
#        [60],
#        [53],
#        [14],
#        [ 5],
#        [51],
#        [31],
#        [18],
#        [59],
#        [65],
#        [10],
#        [24],
#        [86],
#        [48],
#        [40],
#        [97],
#        [72],
#        [20],
#        [90],
#        [10],
#        [ 0],
#        [62],
#        [93],
#        [94],
#        [88],
#        [72],
#        [39],
#        [18],
#        [64],
#        [ 8],
#        [73],
#        [56],
#        [ 8],
#        [45],
#        [73],
#        [17],
#        [84],
#        [40],
#        [35],
#        [23],
#        [81],
#        [23],
#        [98],
#        [90],
#        [ 6],
#        [59],
#        [37],
#        [76],
#        [25],
#        [26],
#        [96],
#        [99],
#        [32],
#        [51],
#        [94],
#        [24],
#        [ 2],
#        [49],
#        [75],
#        [17],
#        [33],
#        [22],
#        [42],
#        [88],
#        [99]])

# %%
arr2
# Out:
# array([60, 27,  5,  7, 21, 84, 82, 46, 66, 96, 91, 63, 93, 19, 45, 16, 11,
#        97, 55, 11,  3, 21, 33, 89, 37, 77, 67, 87, 93, 59, 28, 16, 53,  3,
#        49, 80, 44, 27, 81, 57, 99, 65, 61, 40, 90, 75,  0, 10, 24, 32, 22,
#        34, 81,  5, 56, 31, 15, 29, 20, 96, 72, 35, 82, 33, 80, 82, 93, 38,
#        91, 21, 66, 48,  0, 85, 21, 13, 13, 44, 22, 63, 17, 11, 25, 90, 68,
#        84, 91, 44,  1, 61, 83, 29, 96,  1, 79, 22, 89, 13, 99,  0])
